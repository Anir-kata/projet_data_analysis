# %%
print("hello world")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       4 PROJECT_ROOT = Path.cwd().parents[0] if Path.cwd().name == "notebooks" else Path.cwd()
#       5 sys.path.append(str(PROJECT_ROOT / "src"))
# ----> 7 from ingestion.load_data import load_raw_energy_data
#       8 from preprocessing.clean_data import clean_energy_data
#       9 from analysis.descriptive_stats import compute_basic_kpis, yearly_aggregates
#
# File c:\Users\EKAN\Desktop\energy-data-project\src\ingestion\load_data.py:4
#       1 from pathlib import Path
#       2 import pandas as pd
# ----> 4 from src.config import DEFAULT_RAW_FILE
#       5 from src.logging_utils import get_logger
#       7 logger = get_logger(__name__)
#
# ModuleNotFoundError: No module named 'src'
